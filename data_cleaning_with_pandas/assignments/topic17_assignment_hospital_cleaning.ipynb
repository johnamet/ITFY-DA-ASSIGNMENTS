# %% [markdown]
# # Topic 17 Assignment — Hospital Patient Data Cleaning
#
# **Dataset:** `data_cleaning_with_pandas/data/hospital_patients_messy.csv`
#
# This assignment is based on the Topic 17 live-coding exercise. Your job is to audit, clean, validate, and export hospital patient records.

# %%
import pandas as pd
import numpy as np

HOSPITAL_PATH = "./data/hospital_patients_messy.csv"

# %% [markdown]
# ---
# ## Part 1 — Load and Audit

# %%
# TODO 1: Load the hospital dataset into hosp.
# Print shape, head(), info(), missing values, and unique values for key categorical columns.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 2 — Cleaning Plan
#
# Before fixing anything, document the problems you found.

# %%
# TODO 2: Complete this cleaning plan dictionary.

problems = {
    # "column_name": "problem description and planned fix",
}

for column, plan in problems.items():
    print(f"{column}: {plan}")

# %% [markdown]
# ---
# ## Part 3 — Clean the Data

# %%
# TODO 3: Strip whitespace from patient_name.

# YOUR CODE HERE

# %%
# TODO 4: Remove duplicate patient IDs.

# YOUR CODE HERE

# %%
# TODO 5: Standardise region names.

# YOUR CODE HERE

# %%
# TODO 6: Clean the age column.
# Convert to numeric, replace impossible ages (<0 or >120) with NaN,
# then fill missing ages with the median age.

# YOUR CODE HERE

# %%
# TODO 7: Standardise gender and ward values.

# YOUR CODE HERE

# %%
# TODO 8: Parse admission_date and discharge_date with pd.to_datetime().

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 4 — Validate Length of Stay

# %%
# TODO 9: Create expected_los from discharge_date - admission_date.
# Flag rows where expected_los does not match length_of_stay.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 5 — Final Audit and Export

# %%
# TODO 10: Run a post-cleaning audit.
# Print shape, missing values, duplicate IDs, cleaned categories, and LOS mismatch count.

# YOUR CODE HERE

# %%
# TODO 11: Export the cleaned data to:
# data_cleaning_with_pandas/data/hospital_patients_clean.csv

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 6 — Interpretation
#
# Write 4-6 sentences explaining:
# 1. the most important data quality issues you found
# 2. how you fixed them
# 3. what issues should still be verified with the hospital records team

# %% [markdown]
# **Your interpretation:**
#
# *(Write your answer here.)*
