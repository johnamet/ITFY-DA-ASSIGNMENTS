# %% [markdown]
# # Topic 15 Assignment — Kumasi Climate Analysis with NumPy
#
# **Dataset:** `numerical_python_numpy/data/kumasi_climate_2023.csv`
#
# This assignment is based on the Topic 15 live-coding exercise. You will load, clean, summarise, and interpret Kumasi climate data using NumPy.

# %%
import numpy as np

KUMASI_PATH = "numerical_python_numpy/data/kumasi_climate_2023.csv"

# %% [markdown]
# ---
# ## Part 1 — Load the CSV
#
# Load the CSV manually using Python file handling, then convert the numeric columns into NumPy arrays.

# %%
# TODO 1: Load Kumasi data.
# Create these lists first, then convert them to NumPy arrays:
# k_dates, k_temperatures, k_rainfall, k_humidity, k_wind

k_dates = []
k_temperatures = []
k_rainfall = []
k_humidity = []
k_wind = []

# YOUR CODE HERE

# Convert to arrays here:
# k_temp_arr = ...
# k_rain_arr = ...
# k_humid_arr = ...
# k_wind_arr = ...

print("Days loaded:", len(k_dates))

# %% [markdown]
# ---
# ## Part 2 — Clean the Data

# %%
# TODO 2: Fix impossible rainfall values.
# Replace negative rainfall with 0.0 in a copy called k_rain_clean.

# YOUR CODE HERE

# %%
# TODO 3: Detect temperature outliers using the IQR method.
# Replace outlier temperatures with the median in a copy called k_temp_clean.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 3 — Summary Statistics

# %%
# TODO 4: Print annual summary statistics.
# Include mean, median, standard deviation, hottest day, coolest day,
# total rainfall, rainy days, dry days, and mean humidity.

# YOUR CODE HERE

# %%
# TODO 5: Create a monthly rainfall summary.
# Print month name, average temperature, total rainfall, and rainy days.

month_names = ["Jan","Feb","Mar","Apr","May","Jun", "Jul","Aug","Sep","Oct","Nov","Dec"]
days_in_month = [31,28,31,30,31,30,31,31,30,31,30,31]

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 4 — Interpretation
#
# Write 3-5 sentences explaining Kumasi's 2023 climate pattern.
# Mention temperature, rainfall, and any data quality issues you fixed.

# %% [markdown]
# **Your interpretation:**
#
# *(Write your answer here.)*
