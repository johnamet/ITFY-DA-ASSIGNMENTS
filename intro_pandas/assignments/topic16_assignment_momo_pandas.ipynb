# %% [markdown]
# # Topic 16 Assignment — MoMo Transactions with pandas
#
# **Dataset:** `intro_pandas/data/momo_transactions_500.csv`
#
# This assignment is based on the Topic 16 live-coding exercise. You will load, inspect, filter, sort, summarise, and interpret mobile money transaction data.

# %%
import pandas as pd

MOMO_PATH = "intro_pandas/data/momo_transactions_500.csv"

# %% [markdown]
# ---
# ## Part 1 — Load and Inspect

# %%
# TODO 1: Load the dataset into a DataFrame called momo.
# Print shape, head(), dtypes, and info().

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 2 — Basic Cleaning Checks

# %%
# TODO 2: Check missing values and duplicate transaction IDs.
# Print value counts for status, transaction_type, and network_provider.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 3 — Filtering

# %%
# TODO 3A: How many successful transfers are in the dataset?

# YOUR CODE HERE

# %%
# TODO 3B: What is the average transaction amount for MTN users?

# YOUR CODE HERE

# %%
# TODO 3C: How many transactions were sent from Greater Accra to Ashanti?

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 4 — Counts and Sorting

# %%
# TODO 4: Show distribution of transaction types and network providers.
# Then display the top 10 largest transactions.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 5 — Mini Analysis

# %%
# TODO 5A: Which network provider processes the highest average amount?

# YOUR CODE HERE

# %%
# TODO 5B: What percentage of transactions failed?

# YOUR CODE HERE

# %%
# TODO 5C: Which transaction type has the highest total transaction value?

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 6 — Interpretation
#
# Write 4-6 sentences explaining what the transaction data suggests about network usage, failed transactions, and high-value transaction types.

# %% [markdown]
# **Your interpretation:**
#
# *(Write your answer here.)*
