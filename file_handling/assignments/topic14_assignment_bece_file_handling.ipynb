# %% [markdown]
# # Topic 14 Assignment — BECE Results File Handling
#
# **Dataset:** `file_handling/data/bece_results.txt`
#
# This assignment extends Topic 14. You will manually load and analyse a pipe-separated text file using core Python file-handling skills.
#
# ## What You Must Submit
#
# Complete every `TODO` cell and run the notebook from top to bottom.
#
# Your finished notebook should show:
# - the raw file preview
# - parsed records as dictionaries
# - cleaned numeric fields
# - regional pass-rate summaries
# - top-performing schools
# - a short written interpretation

# %% [markdown]
# ---
# ## Part 1 — Load and Preview the File
#
# The file is **pipe-separated**, meaning the delimiter is `|`.

# %%
FILE_PATH = "file_handling/data/bece_results.txt"

with open(FILE_PATH, "r", encoding="utf-8") as f:
    raw_content = f.read()

print("First 500 characters:")
print(raw_content[:500])
print()
print("Total characters:", len(raw_content))

# %%
# TODO 1: Read the file line by line into a variable called lines.
# Then print the number of lines and the raw header line.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 2 — Parse Rows into Dictionaries

# %%
# TODO 2: Split the header using "|" to create a columns list.
# Print each column with its index.

# YOUR CODE HERE

# %%
# TODO 3: Build a list called records.
# Each record should be a dictionary created with dict(zip(columns, parts)).
# Skip blank lines and rows that do not match the header length.

records = []
skipped = 0

# YOUR CODE HERE

print("Records loaded:", len(records))
print("Rows skipped:", skipped)
print("First record:")
# print(records[0])

# %% [markdown]
# ---
# ## Part 3 — Clean the Data
#
# Clean these fields:
# - `Region`: strip spaces and standardise capitalisation
# - `Year`: convert values like `2022/23` to `2023` or choose a consistent rule and explain it
# - `Candidates`: convert to integer
# - `Passes`: convert to integer
# - `Pass_Rate`: convert to float; if missing, calculate `Passes / Candidates * 100`

# %%
# TODO 4: Write a function called clean_region(raw) and apply it to every record.

def clean_region(raw):
    # YOUR CODE HERE
    return raw

# YOUR CODE HERE

# %%
# TODO 5: Convert Candidates, Passes, and Pass_Rate.
# If Pass_Rate is blank, calculate it from Passes and Candidates.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 4 — Analyse

# %%
# TODO 6: Calculate the overall pass rate across all schools.
# Formula: total passes / total candidates * 100

# YOUR CODE HERE

# %%
# TODO 7: Calculate pass rate by region.
# Build a dictionary like:
# region_summary[region] = {"Candidates": ..., "Passes": ...}

region_summary = {}

# YOUR CODE HERE

# Print each region with candidates, passes, and pass rate.

# %%
# TODO 8: Show the top 10 schools by Pass_Rate.
# Print School_Name, Region, Candidates, Passes, and Pass_Rate.

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 5 — Interpretation
#
# Write 3-5 sentences answering:
#
# 1. Which region had the strongest BECE performance?
# 2. Did any schools have suspicious or incomplete data?
# 3. What would you ask the data provider to verify?

# %% [markdown]
# **Your interpretation:**
#
# *(Write your answer here.)*

# %%
# Optional Extension:
# Write a cleaned CSV file called file_handling/data/bece_results_clean.csv.

# YOUR CODE HERE
